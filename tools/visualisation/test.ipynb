# %%
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np
import cv2

# %%
a = cv2.imread("testing.jpg")
print(a.shape)
# b = np.ones(a.shape)*255
# a = np.concatenate((a,b), axis = 0)
# print(a.shape)
# np.max(a)
# Out:
# (32, 32, 3)

# %%
plt.imshow(a)
for i in range(10):
    plt.text(0, -(0.1 + i*0.1)*a.shape[0], f"[ hello {i} ]")
# plt.plot([0, 1, 2, 3, 4], [0, 3, 5, 9, 11])
plt.savefig("out.jpg", bbox_inches='tight')

# %%
plt.savefig("out.png")

# %%
plt.show()

# %%
cd /mnt/disk1/jatin/pytorch-classification
# Out:
# /mnt/disk1/jatin/pytorch-classification

# %%
# !pwd
# Out:
# /mnt/disk1/jatin/pytorch-classification

# %%
import time
import pickle
a = time.time()
b = []
for i in range(100000):
    b.append(i)
    # f = open("test.pickle", "wb")
    # pickle.dump(b, f)
    # f.close()

f = open("test.pickle", "wb")
pickle.dump(b, f)
f.close()
print(time.time()-a)
# Out:
# 0.04176163673400879
