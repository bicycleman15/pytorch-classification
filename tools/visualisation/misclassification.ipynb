# %% [markdown]
# # Change the directory first

# %%
cd /mnt/disk1/jatin/pytorch-classification
# Out:
# /mnt/disk1/jatin/pytorch-classification

# %%
import cv2
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

from data_loaders import dataset_dict, dataset_nclasses_dict, dataset_class_dict

# %%
class temp_args():
    def __init__(self, dataset):
        self.dataset = dataset 

        assert self.dataset in dataset_dict
        self.train_batch_size =128 
        self.workers = 4
        self.test_batch_size = 1


args = temp_args("cifar10")

# %%
_ , test_ds = dataset_dict[args.dataset](args)
classes = dataset_class_dict[args.dataset]
print(classes)
# Out:
# Files already downloaded and verified
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
from tools.visualisation.misclassification import retiever
# a = input()
newRetriver = retiever(args.dataset, classes=classes)
# Out:
# Found the following runs
# [ 0 : cifar1010-April-cifar10_resnet_depth=32_lossname=LS+MDCA_alpha=0.05_beta=40_lr=0.1 ]
# [ 1 : resnet3419-April-LSFL_alpha=0.05_gamma=3.0 ]
# [ 2 : resnet3419-April-LSFL_alpha=0.1_gamma=3.0 ]
# [ 3 : resnet3419-April-LSFL_alpha=0.05_gamma=1.0 ]
# [ 4 : resnet3419-April-LSFL_alpha=0.1_gamma=1.0 ]
# [ 5 : resnet3419-April-LSFL_alpha=0.1_gamma=2.0 ]
# [ 6 : resnet3419-April-LSFL_alpha=0.05_gamma=2.0 ]
# [ 7 : cifar109-April-cifar10_resnet_depth=32_lossname=NLL_lr=0.1 ]
# [ 8 : cifar109-April-cifar10_resnet_depth=32_lossname=FL_gamma=3.0_lr=0.1 ]

# %%
preferences = [1,2,3,4,5,6]
newRetriver.set_perferences(preferences)
# Out:
# Final set prepared with 165 common misclassifications

# %%
! rm outputs/misclassification/results_images/*

# %%
newRetriver.save_imgs(test_ds)
# Out:
# ...
#   7%|▋         | 11/165 [00:16<03:49,  1.49s/it]

# %%
n = 12
plt.rcParams["figure.figsize"] = (3*n,5)
figure, axis = plt.subplots(1, n)
a = np.random.rand(34,34,3)
# plt.imshow(a)
print(axis)
# for i in range(10):
for i in range(n):
    # axis[i].plot([0, 1, 2, 3, 4], [0, 3, 5, 9, 11])
    axis[i].imshow(a)
    for j in range(10):
        axis[0,i].text(0, (1.2 + j*0.1)*a.shape[0], f"[ hello {i} ]")
# plt.show()
# figure.savefig("test.jpg")
figure.savefig("test.jpg", bbox_inches='tight')
# plt.clf()
figure.show()

# plt.savefig("out.jpg", bbox_inches='tight')
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-5ce0e0e17e4b> in <module>
#       8 for i in range(n):
#       9     # axis[i].plot([0, 1, 2, 3, 4], [0, 3, 5, 9, 11])
# ---> 10     axis[i].imshow(a)
#      11     for j in range(10):
#      12         axis[0,i].text(0, (1.2 + j*0.1)*a.shape[0], f"[ hello {i} ]")
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
_ , test_ds = dataset_dict[args.dataset](args)

# %%
img = np.array(test_ds[0][0])
plt.imshow(img)
for i in range(10):
    plt.text(0, (1.2 + i*0.1)*a.shape[0], f"[ hello {i} ]")

plt.savefig("test.jpg", bbox_inches='tight')

# %%
cd /mnt/disk1/jatin/pytorch-classification

# %%
# !pwd

# %%
import time
import pickle
a = time.time()
b = []
for i in range(100000):
    b.append(i)
    # f = open("test.pickle", "wb")
    # pickle.dump(b, f)
    # f.close()

f = open("test.pickle", "wb")
pickle.dump(b, f)
f.close()
print(time.time()-a)
